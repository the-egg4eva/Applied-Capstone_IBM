# %% [markdown]
# # Problem Description

# %% [markdown]
# India is the 2nd largest populous country with a rapidly growing economy which makes it a huge market for buisness and investors.Mumbai is called the Economic capital of  India.So many investors and banks would like to invest in the city.
#
# But Mumbai despite being one of the promising cities of the world has impoverished areas too like Dharavi and the areas itself are diversified .
# We would like to define  the areas and categorise them according to the type of venues they are rich in.

# %% [markdown]
# # Data

# %% [markdown]
# The Data we use is Mumbai Neighborhoods list from wikipedia.<href>https://en.wikipedia.org/wiki/List_of_neighbourhoods_in_Mumbai<href>
#
# And Foursquare API for exploring venues in Neighborhoods.
