# %% [markdown]
#  # <i> This Notebook is solely for Applied Capstone Project IBM <i>

# %%
import numpy as np
import pandas as pd

# %%
print("Hi Capstone Project Coursera!")
# Out:
# Hi Capstone Project Coursera!
