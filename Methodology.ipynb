# %% [markdown]
# # Introduction

# %% [markdown]
# India is large country with rapidly emerging economy ,It is also the second populous country in the world.Factors like these make it suitable for the buisness investors and banks to invest in the economies
#
# Mumbai is dubbed as the Economic capital of India and is one of the richest countries in the world.
#
# So inorder to take this oppurtunity and develop further from it the local banks would like to invest here and prosper from it,Observe that this a win-win situtation for both the parties as it also helps in expanding their individual ventures.
#
#
# We would like to analyise the Mumbai city select which areas and type of venutures are suitable for the investement.

# %% [markdown]
# # Data

# %% [markdown]
# we would want to use the Neighborhood list of mumabi :<href>https://en.wikipedia.org/wiki/List_of_neighbourhoods_in_Mumbai
#
# foursquare API to get the venues data from requierd locations.<href>https://developer.foursquare.com/

# %% [markdown]
# # Methodology

# %% [markdown]
# - import necessary libraries
# - Read the neighborhood list into Pandas DataFrame
# - Get venues according to the neighborhood locations with the help of foursquare API
# - clean the data and remove any NAN values
# - correct if there are any syntactical errors
#
# <i> Data Analysis<b> :

# %% [markdown]
# - we are interested in the locations where there are more venues and diversification of venues.
#
# <i>Our DataAnalysis is done based on two conditions:

# %% [markdown]
# - This is done based on counting of the categories in each location
# - Select location with have atleast 5 venues of same category
# - Filter Location based on diversity of Categories (remove if it has less than 2 different categories)
# - Plot the bar charts to visualize the frequency of the categories for each neighboirhood and their diversification of neighboirhoods
# - Also visualize the distributions of each filtered Neighborhood with Folium Cluster Marker Plugin to get an idea of the clusters in the location

# %% [markdown]
# # Result

# %% [markdown]
# From our above data analysis we have found out that South Mumbai Area is suitable for investment as it is rich in all the below categories:
#
# - Antique Shops
# - Art Gallerys
# - Boutiques
# - Bridal Shops
# - Cafeterias
# - Chaat Places
# - Coffee Shops
# Dumpling Restaurants
# Goan Restaurants
# Harbor / Marinas
# History Museums
# Hot Springs
# Indian Restaurants
# Indoor Play Areas
# Lighthouses
# Maharashtrian Restaurants
# Mediterranean Restaurants
# Mexican Restaurants
# Monument / Landmarks
# Movie Theaters
# Mughlai Restaurants
# Parsi Restaurants
# Roof Decks
# Salon / Barbershops
# Seafood Restaurants
# Shopping Malls
# Soccer Fields
# Theaters
# Vegetarian / Vegan Restaurants
# Whisky Bars
# Wine Bars

# %% [markdown]
# # Conclusion

# %% [markdown]
# Select the location which satisfies the two mentioned conditions and select the top 5 categories of the selected top Location
#
# - This is the desired location for the banks to invest in because of their rich denisity of the venues and diversity of venues categories
