# %% [markdown]
# # Introduction:
#
# India is large country with rapidly emerging economy ,It is also the second populous country in the world.Factors like these make it suitable for the buisness investors and banks to invest in the economies
#
# Mumbai is dubbed as the Economic capital of India and is one of the richest countries in the world.
#
# So inorder to take this oppurtunity and develop further from it the local banks would like to invest here and prosper from it,Observe that this a win-win situtation for both the parties as it also helps in expanding their individual ventures.
#
# We would like to analyise the Mumbai city select which areas and type of venutures are suitable for the investement.
#
# # Data:
#
# we would want to use the Neighborhood list of mumabi :https://en.wikipedia.org/wiki/List_of_neighbourhoods_in_Mumbai
#
# foursquare API to get the venues data from requierd locations.
#
# # Methodology:
# - import necessary libraries
# - Read the neighborhood list into Pandas DataFrame
# - Get venues according to the neighborhood locations with the help of foursquare API
# - clean the data and remove any NAN values
# - correct if there are any syntactical errors
#
# # Data Analysis :
#
# - we are interested in the locations where there are more venues and diversification of venues.
# - Use pd.get_dummies() to encode the categories of restaturants
# - After using pd.get_dummies:
#
# ### Our DataAnalysis is done based on two conditions:
#
# - get locations which have any category at more than 5 places
# - filter them based on variation in categories (at least it should have 2 different categories)
#
#
#
# ![Data Frame with locations](1.png)
#
# - Above DataFrame shows locations which have even a single place for the category.
# - Such type of venues may come under rare categories(e.g. Amphi Theatre,Museum),as we want popular veunes we do not consider theses categories.
# - After removing categories with only one location,we are left with locations which have atleast 5 restaurants for each category.
#
#
# - But many of these locations have only one category and that is not needed because we need to have a diversified Neighborhood which has varying cuisines.
# - Filter Locations based on diversity of reataurant categories (remove if it has less than 2 different cuisines.
#
# # Final Neighborhoods:
#
# [['South Mumbai', 18],
#  ['Andheri,Western Suburbs', 5],
#  ['Bandra,Western Suburbs', 3]]
#
# # Plotting:
#
# - Plot the distribution of cuisines in above filtered neighborhoods.
#
# ![Bar chart]
# - Bandra has equal dribution of cuisines.
#
#
# Lets look at South Mumbai Distribution:
#
# ![Bar chart of South Mumbai]
#
# Lets look at Andheri Distribution:
#
# ![Bar chart of Andheri]
#
# Top 4 Categories of South Mumbai:
#
# - Indian Restaurant
# - Cafe`
# - Fast Food Restaurant
# - Chineese
#
#
# Folium Map of every venue in South Mumbai:
#
#
#
# # KMeans Clustering :
#
# - Use SKlearn KMeans clustering Algorithm to segregate the finalised Area into clusters such that each inter cluster distance is distingushably large.
# - I have done KMeans clustering with 19 clusters(trial and error approach until all clusters have distinguishable inter cluster distance).
# - Visualize the distributions of each filtered Neighborhood with Folium Cluster Marker Plugin to get an idea of the clusters in the location
#
# - From our above data analysis we have found out that South Mumbai Area has all the below categories:
#
# Antique Shops
# Art Gallerys
# Boutiques
# Bridal Shops
# Cafeterias
# Chaat Places
# Coffee Shops Dumpling Restaurants Goan Restaurants Harbor / Marinas History Museums Hot Springs Indian Restaurants Indoor Play Areas Lighthouses Maharashtrian Restaurants Mediterranean Restaurants Mexican Restaurants Monument / Landmarks Movie Theaters Mughlai Restaurants Parsi Restaurants Roof Decks Salon / Barbershops Seafood Restaurants Shopping Malls Soccer Fields Theaters Vegetarian / Vegan Restaurants Whisky Bars Wine Bars
# And Most importantly we have top 4 categories:
# Top 5 Venues in South Mumbai based on count :
# ========================================
# Indian Restaurant
# ====================
# Cafe
# ====================
# Coffee Shop
# ====================
# Fast Food Restaurant
# ====================
# Link to Project code: Project
#
# Conclusion
# Select the location which satisfies the two mentioned conditions and select the top 5 categories of the selected top Location
#
# Here South Mumbai has very high frequency of restaurant categories and also diversified categories.
# This can be the desired location for the banks to invest in and help the local Buisnesses.
#
#
# Discussion:
# The future of the project is to perform a deatailed analysis of the city with Financial data like revenue and also based on user reviews and ratings.
# With the help of a path searching algorithm to provide an optimal path to given venue category for any given latitude and longitude in the city.
# Limitations:
# This analysis or retrieval of venues is based purely on Foursquare API but compared to google API foursquare API lacks some venues,this is a disadvantage which can be overcome.
# As mentioned above as the target is to provide banks for suitable investment categories and clusters we should consider other features like venue revenue ,customer satisfaction ,vicinity to cultural and tourist attractions.
